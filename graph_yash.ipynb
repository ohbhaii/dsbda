# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv(r"D:\down\heart disease\heart.csv")

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# 5      58    0   0       100   248    0        0      122      0      1.0
# 6      58    1   0       114   318    0        2      140      0      4.4
# 7      55    1   0       160   289    0        0      145      1      0.8
# 8      46    1   0       120   249    0        0      144      0      0.8
# 9      54    1   0       122   286    0        0      116      1      3.2
# 10     71    0   0       112   149    0        1      125      0      1.6
# 11     43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
#barplot using seaborn
sns.barplot(x='sex', y='thalach', data=df)
# Out:
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#scatterplot using seaborn
sns.scatterplot(x='sex', y='thalach', data=df , hue='cp')

# %%
sns.scatterplot(x='age', y='thalach', data=df, hue='cp')

# %%
#barplot using seaborn
sns.boxplot(x='sex', y='thalach', data=df)

# %%
#violinplot using seaborn
sns.violinplot(x='sex', y='thalach', data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4e2fbe76f0f5> in <module>()
#       1 #violinplot using seaborn
# ----> 2 sns.violinplot(x='sex', y='thalach', data=df)
#
# NameError: name 'sns' is not defined

# %%
#lineplot using seaborn
sns.lineplot(x='sex', y='thalach', data=df)
# Out:
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df('thalach'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-442d531af70b> in <module>()
# ----> 1 sns.distplot(df('thalach'))
#
# NameError: name 'sns' is not defined

# %%
plt.displot(df['thalach'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-0b0f95745801> in <module>()
# ----> 1 plt.displot(df['thalach'])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'displot'

# %%
#scatterplot using matplotlib
plt.scatter(df['thalach'], df['sex'])
plt.show()

# %%
plt.scatter(df['thalach'], df['age'])
plt.show()

# %%
plt.violin(df['thalach'], df['age'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-49d0ddbb64df> in <module>()
# ----> 1 plt.violin(df['thalach'], df['age'])
#       2 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'violin'

# %%
plt.bar(df['sex'],df['thalach'])
plt.show()

# %%
val=pd.DataFrame(df['sex'].value_counts())

# %%
val
# Out:
#    sex
# 1  713
# 0  312

# %%
plt.pie(val['sex'], labels= val.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x67314f0>,
# ...
#  [Text(-0.634229,0.898751,'1'), Text(0.634229,-0.898751,'0')])

# %%
plt.figure(figsize=(12,12))
sns.pairplot(df, hue='sex', palette='Blues')
# Out:
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
plt.figure(figsize=(12,12))
sns.pairplot(df, hue= 'sex' , palette = 'Blues')
# Out:
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
sns.violinplot(x='sex', y='thalach', data=df)
# Out:
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.scatter(df['thalach'], df['age'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d4363e24f62f> in <module>()
# ----> 1 plt.scatter(df['thalach'], df['age'])
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.scatter(df['thalach'], df['age'])
plt.show()

# %%
import seaborn as sns
sns.violinplot(x='sex', y='thalach', data=df)
# Out:
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(x='sex', data=df)
# Out:
# C:\Users\EC1023AX\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(data=df, x='cp')

# %%
sns.countplot(data=df, x='cp')

# %%
sns.histplot(data=df,x=df['cp'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-4983a4127179> in <module>()
# ----> 1 sns.histplot(data=df,x=df['cp'])
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
val=df['sex'].value_counts
print(val)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1
# 1       1
# 2       1
# 3       1
# 4       0
# 5       0
# 6       1
# 7       1
# 8       1
# 9       1
# 10      0
# 11      0
# 12      0
# 13      1
# 14      1
# 15      0
# 16      0
# 17      1
# 18      0
# 19      1
# 20      1
# 21      0
# 22      1
# 23      0
# 24      0
# 25      0
# 26      1
# 27      0
# 28      1
# 29      0
#        ..
# 995     1
# 996     0
# 997     1
# 998     1
# 999     1
# 1000    1
# 1001    1
# 1002    1
# 1003    1
# 1004    0
# 1005    0
# 1006    1
# 1007    1
# 1008    1
# 1009    1
# 1010    1
# 1011    1
# 1012    1
# 1013    1
# 1014    0
# 1015    1
# 1016    1
# 1017    1
# 1018    1
# 1019    1
# 1020    1
# 1021    1
# 1022    1
# 1023    0
# 1024    1
# Name: sex, Length: 1025, dtype: int64>

# %%
val = df['sex'].value_counts()
print(val)
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
plt.pie(val['sex'], labels= val.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x100e1250>,
# ...
#  [Text(-0.634229,0.898751,'1'), Text(0.634229,-0.898751,'0')])

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
x=np.random.normal(50, 100, 150)
plt.hist(x)
plt.show()
